# %% [markdown]
# ## model training (yolo architectur) with 10 epoch batch 2 adawm optimizer

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(
    data="/home/user171125/Documents/multiple_food_detction/data.yaml",
    epochs=10,
    imgsz=640,
    batch=2,
    workers=0,
    device="cpu",
    patience=10,
    plots=True,       # <<< TRACK LOSS & ACCURACY
    verbose=True      # <<< DETAILED TRAIN LOGS
)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.3.237 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.236 🚀 Python-3.10.19 torch-2.9.1+cu128 CPU (12th Gen Intel Core i5-12400F)
# ...

# %%
from ultralytics import YOLO

model_path = "/home/user171125/Documents/multiple_food_detction/runs/detect/train5/weights/last.pt"

model = YOLO(model_path)

results = model.train(
    data="/home/user171125/Documents/multiple_food_detction/data.yaml",
    epochs=20,           
    resume=False         
)

print("Training continued for 10 epochs successfully.")
# Out:
# New https://pypi.org/project/ultralytics/8.3.239 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.236 🚀 Python-3.10.19 torch-2.9.1+cu128 CPU (12th Gen Intel Core i5-12400F)
# ...
